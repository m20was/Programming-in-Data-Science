# %%
# use html tags to define the header  (1)

# %% [markdown]
# <H1> # This is my world </H1>
# <H2> # Welcome </H2>

# %%
# Explain the Object Oriented Programming concepts        (3)

# %% [markdown]
# Main concepts of object oriented programming in Python are class,objects,polymorphism,encapsulation,inheritance,data abstraction.
# A class is a collection of objects and it contains blueprints or prototypes being created.
#
# The object is an entity that has a state and behaviour associated with it.
#
# Object consists of:
# "state" which is represented by attributes of an object.
# "Behaviour" which is represented by methods of an object
# "identity" which gives an unique name to an object
# Inheritance is the capability of one class to derive or inherit properties from another class
# Benefits- represents real world relationships well, provides reusability of a code.
# Polymorphism means having many forms
# Encapsulation describes the idea of wrapping data and methods that work on data within one unit.

# %%
# print factors
# input = 100, output = [1, 2, 4, 5, 10, 20, 25, 50, 100]

# Add comments wherever needed      (3)

# %%
def printfactors(n):
    i=1
    while i <=n :
        if(n%i==0):
            print(i,end=" ")
        i=i+1
printfactors(100)
# Out:
# 1 2 4 5 10 20 25 50 100

# %%
# Add 45 days to the list and print it as due date (3)
# use functions datetime, strptime, timedelta 
import datetime as dt
names_list =[{
    "name": "Joe",
    "issue_date":"30-12-2022"},
    {"name": "John",
    "issue_date":"15-01-2022"}]

# %%
from datetime import datetime 
from datetime import timedelta 

names_list =[{
    "name": "Joe",
    "issue_date":"30-12-2022"},
    {"name": "John",
    "issue_date":"15-01-2022"}]

for i in names_list:
    new = datetime.strptime(i["issue_date"],"%d-%m-%Y") + timedelta(days=45)
    i["Due_date"]=str(new.date())
    print(i)
# Out:
# {'name': 'Joe', 'issue_date': '30-12-2022', 'Due_date': '2023-02-13'}
# {'name': 'John', 'issue_date': '15-01-2022', 'Due_date': '2022-03-01'}
