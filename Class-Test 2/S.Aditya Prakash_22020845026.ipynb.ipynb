# %%
# use html tags to define the header  (1)

# %%
# Explain the Object Oriented Programming concepts        (3)

# %%
# print factors
# input = 100, output = [1, 2, 4, 5, 10, 20, 25, 50, 100]

# Add comments wherever needed      (3)

# %%
# Add 45 days to the list and print it as due date (3)
# use functions datetime, strptime, timedelta 

from datetime import datetime 
from datetime import timedelta
names_list =[{
    "name": "Joe",
    "issue_date":"30-12-2022"},
    {"name": "John",
    "issue_date":"15-01-2022"}]

for i in names_list:
    new = datetime.strptime( i["issue_date"], "%d-%m-%Y")+timedelta(days = 45)
    i["due_date"] = str(new.date())
    print(i)
# Out:
# {'name': 'Joe', 'issue_date': '30-12-2022', 'due_date': '2023-02-13'}
# {'name': 'John', 'issue_date': '15-01-2022', 'due_date': '2022-03-01'}

# %%
# print factors
# input = 100, output = [1, 2, 4, 5, 10, 20, 25, 50, 100]

# Add comments wherever needed

def printfactors(n):
i=1
    while i <=n:
    if(n%i==0) :
        print(i,end=" ") :
        i=i+1
        
        printfactors(100)
# Out:
#   Input In [17]
#     i=1
#     ^
# IndentationError: expected an indented block

# %%
# Explain the Object Oriented Programming concepts 

#OOP in python is a programming paradigm that provides a means of structuring programs so that properties and behaviours are bundled into indivisual objects . the fuctions and members are represented , called and defined using objects. Some of the most important elements of OOP are 
#class - collection of objects , contains blueprints or the prototypes from which the objects are being created.
#objects -it is an entity that has state and behaviour oriented with it , consist of state, behaviour and identity
#polymorphism - it is the feature of having many forms.
#encapsulation - it os the feature of wrapping data and the methods that work on datat within a single unit.
#inheritance - it is the capability of one class to derive and inherit features from its parent class. single , multilevel , hierechical , multiple.
#data abstarction - hiding unnecessary code from the user

# %%
#heading are titles or subtitles that you want to display on a webpage - h1 to h6 tags
<h1> Heading 1</h1>
<h2> Heading 1</h2>
<h3> Heading 1</h3>
<h4> Heading 1</h4>
<h5> Heading 1</h5>
<h6> Heading 1</h6>

# %%
# Add 45 days to the list and print it as due date 
# use functions datetime, strptime, timedelta 

from datetime import datetime
from datetime import timedelta

#taking input as date

start_date_string = "07-09-2022"

#convert string to dt object 

start_date =  datetime.strptime(start_date_string, "%d-%m-%y")

#print start date

print("start date")
print(start_date)

#calculating due date
due_date = start_date + timedelta (days = 45)

#print end date
print("due date")
print(due_date)
