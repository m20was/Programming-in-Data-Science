# %% [markdown]
# # use html tags to define the header  (1)
#
# <html>
# <body>
#     <h1>Symbiosis Institute of Business Management, Bengaluru </h1>
#     <h3>Address: 95/1, 95/2, Hosur Rd, Electronics City Phase 1, Electronic City, Bengaluru, Karnataka 560100</h3>
#     <hr>
#     <article>
#         <header>
#             <h3>Business Analytics</h3>
#
# <p>Posted by ADCOM</p>

# %% [markdown]
# # Explain the Object Oriented Programming concepts        (3)
#
#
# In Python, object-oriented Programming (OOPs) is a programming paradigm that uses objects and classes in programming. It aims to implement real-world entities like inheritance, polymorphisms, encapsulation, etc. in the programming. The main concept of OOPs is to bind the data and the functions that work on that together as a single unit so that no other part of the code can access this data.
#
# Main Concepts of Object-Oriented Programming (OOPs)
# Class
# Objects
# Polymorphism
# Encapsulation
# Inheritance
# Data Abstraction

# %%
# print factors
# input = 100, output = [1, 2, 4, 5, 10, 20, 25, 50, 100]

# Add comments wherever needed      (3)



def printfactors(n) :
    i = 1
    while i <= n :
        if (n % i==0) :
            print (i,end=" ")
        i = i + 1
         

print ("The factors of 100 are: ")
printfactors(100)
# Out:
# The factors of 100 are:
# 1 2 4 5 10 20 25 50 100

# %%
# Add 45 days to the list and print it as due date (3)
# use functions datetime, strptime, timedelta 
import datetime as dt
names_list =[{
    "name": "Joe",
    "issue_date":"30-12-2022"},
    {"name": "John",
    "issue_date":"15-01-2022"}]

for i in names_list:
        iss_dt = i["issue_date"]
        fmt_dt = datetime.datetime.strptime(iss_dt, "%d-%m-%Y")
        due_dt = fmt_dt + datetime.timedelta(days=45)
        i["due_date"] = str(due_dt.date())
        print(i)

# issue_date = "30/12/2022"
# Due = datetime.datetime.strptime(issue_date, "%d/%m/%y")
# Due_date = issue_date_temp + datetime.timedelta(days=45)

# print(Due_date)
# Out:
# {'name': 'Joe', 'issue_date': '30-12-2022', 'due_date': '2023-02-13'}
# {'name': 'John', 'issue_date': '15-01-2022', 'due_date': '2022-03-01'}
