# %% [markdown]
# Latex to write mathematical

# %% [markdown]
# $$\int_0^{2\pi} f(r, \phi) \partial \phi $$

# %% [markdown]
# <h3 style="color:blue;"> </h3>

# %% [markdown]
# <img src="https://www.qries.com/images/banner_logo.png">

# %% [markdown]
# <img src='Logo Image.png' >

# %% [markdown]
# #### heading

# %% [markdown]
# You can use html

# %% [markdown]
# <h1> This is a heading </h1>

# %%
print(x)

# %% [markdown]
# <h2> This is a heading </h2>
