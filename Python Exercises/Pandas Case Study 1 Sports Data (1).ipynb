# %% [markdown]
# <br>
# <p style="font-family:Georgia; font-size:2.6em;color:Black; font-style:bold; font-weight:700"><br>
# Case Study on Olympic Sports Medal Data </p><br>
# <br>
# <br>
# <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1 style="font-family:Georgia; font-size:1.75em;color:black; font-weight:500">
# About Olympics </h1>
#
# * The Olympic Games are considered the world's foremost sports competition with more than 200 nations participating.
# * The Olympic Games are normally held every four years, and since 1994, have alternated between the Summer and Winter Olympics every two years during the four-year period.

# %% [markdown]
# <h2 style="font-family:Georgia; font-size:1.75em;color:black; font-weight:500">
# About Input Data </h2>
#
# * 2.7 lakhs records from 1184 countries from 1904 to 2016
# * 16 columns describing the Name, Year, Country, Sports, Medal(won if any), Age, Weight, Height

# %% [markdown]
# Reference doc
# * What is EDA ? <br>
#    https://www.geeksforgeeks.org/exploratory-data-analysis-eda-types-and-tools/
# * EDA with an example: <br>
#    https://www.geeksforgeeks.org/what-is-exploratory-data-analysis/

# %% [markdown]
# * Top 10 countries based on Medal (gold) Tally
# * Top 10 countries based on participation
# * Participation trend by country,Teams over the years

# %% [markdown]
# #### Import the required library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Read files

# %%
# read the file directly from google drive
url = "https://drive.google.com/file/d/16_eSW0jjtApGi3QnFnceTce-mLEdxx8e/view?usp=sharing"
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
df = pd.read_csv(dwn_url)
print(df.head())
# Out:
#    ID               Name Gender_1  Age_1  Height  Weight     Team  NOC  \
# 0  22      Andreea Aanei        F   22.0   170.0   125.0  Romania  ROU
# 1  51  Nstor Abad Sanjun        M   23.0   167.0    64.0    Spain  ESP
# 2  51  Nstor Abad Sanjun        M   23.0   167.0    64.0    Spain  ESP
# 3  51  Nstor Abad Sanjun        M   23.0   167.0    64.0    Spain  ESP
# 4  51  Nstor Abad Sanjun        M   23.0   167.0    64.0    Spain  ESP
#
#          Games  Year  Season            City          Sport  \
# 0  2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 1  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 2  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 3  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 4  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                      Event Medal
# 0  Weightlifting Women's Super-Heavyweight   NaN
# 1   Gymnastics Men's Individual All-Around   NaN
# 2          Gymnastics Men's Floor Exercise   NaN
# 3           Gymnastics Men's Parallel Bars   NaN
# 4          Gymnastics Men's Horizontal Bar   NaN

# %%
file_id
# Out:
# '16_eSW0jjtApGi3QnFnceTce-mLEdxx8e'

# %%
df = pd.read_csv('C:\\Rekha\\InputFiles\\Sports_Event_Medal_Dataset.csv')

# %% [markdown]
# ### Exploring data
# df.head() , df.shape , df.info()

# %%
df.head(2)
# Out:
#    ID               Name Gender_1  Age_1  Height  Weight     Team  NOC  \
# 0  22      Andreea Aanei        F   22.0   170.0   125.0  Romania  ROU
# 1  51  Nstor Abad Sanjun        M   23.0   167.0    64.0    Spain  ESP
#
#          Games  Year  Season            City          Sport  \
# 0  2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 1  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                      Event Medal
# 0  Weightlifting Women's Super-Heavyweight   NaN
# 1   Gymnastics Men's Individual All-Around   NaN

# %%
df.info()

# %%
df.size

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.describe()
# Out:
#                   ID          Age_1         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# #### View data from selected columns on which analysis will be done.

# %%
#Selecting multiple columns
df[["Age","Year"]].head(2)

# %%
#Selecting multiple columns
df.Age.head(2)

# %% [markdown]
# #### Get unique values for categorical data

# %%
df.nunique(axis=0)

# %%
df["Team"].value_counts()

# %%
cols = ["Team","Year","Games"]
df[cols].nunique()
# Out:
# Team     1184
# Year       35
# Games      51
# dtype: int64

# %%
df["Year"].max()

# %%
df.Sport.value_counts()

# %%
df.Height.value_counts()

# %%
# Identify unique country names
df.Team.unique()  # .size

# %%
df.Year.unique()

# %% [markdown]
# #### Clean up the data : Rename columns, Replace values in the dataframe,Format date if any
# #### Drop columns, Remove duplicates,Address null values

# %%
df.rename(columns = {'Gender_1':'Gender','Age_1':'Age'}, inplace = True)
df.head(1)
# Out:
#    ID           Name Gender   Age  Height  Weight     Team  NOC        Games  \
# 0  22  Andreea Aanei      F  22.0   170.0   125.0  Romania  ROU  2016 Summer
#
#    Year  Season            City          Sport  \
# 0  2016  Summer  Rio de Janeiro  Weightlifting
#
#                                      Event Medal
# 0  Weightlifting Women's Super-Heavyweight   NaN

# %%
df.replace({"Gender":{'M':'Male','F':'Female'}}).head(2)

# %% [markdown]
# #### Adding a new column of date type and formating it

# %%
df["Height"] = round(df["Height"]/30,2)
df.head(3)
# Out:
#    ID               Name Gender   Age  Height  Weight     Team  NOC  \
# 0  22      Andreea Aanei      F  22.0    0.19   125.0  Romania  ROU
# 1  51  Nstor Abad Sanjun      M  23.0    0.19    64.0    Spain  ESP
# 2  51  Nstor Abad Sanjun      M  23.0    0.19    64.0    Spain  ESP
#
#          Games  Year  Season            City          Sport  \
# 0  2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 1  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 2  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                      Event Medal
# 0  Weightlifting Women's Super-Heavyweight   NaN
# 1   Gymnastics Men's Individual All-Around   NaN
# 2          Gymnastics Men's Floor Exercise   NaN

# %%
df["BeginDate"] = pd.to_datetime(df.Year,format="%Y")
df["BeginDate"].dt.strftime("%d-%m-%Y")
df.info()
#pd.to_datetime("1900",format="%Y").strftime("%d-%m-%Y")

# %%
df.drop(columns =['NOC']) # df.drop(columns =['C', 'D']) ==> Multi Column

# %%
df.duplicated().sum()

# %%
# List the duplicates
df[df.duplicated()]

# %%
# Drop the duplicates
df.drop_duplicates()

# %%
#Working with missing values
df.isnull().sum() # of isna

# %% [markdown]
# #### * dropping column if it has less than 910 not-null value
# #### * or dropping rows with null values

# %%
df.dropna(thresh=270000,axis=1) # axis = 1 columns, we can give threshold to control the drop

# %%
df.dropna(axis=0)

# %%
df.Medal.fillna("None")
#df.Medal.fillna(method='backfill')
#df.Medal.fillna(method='ffill')
# Out:
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
#            ...
# 271111      None
# 271112    Silver
# 271113    Silver
# 271114      None
# 271115      Gold
# Name: Medal, Length: 271116, dtype: object

# %%
#Creating a test file
# df = pd.read_csv('C:\\Rekha\\InputFiles\\Sports_Event_Medal_Dataset.csv')
# sportsFilter = ['Athletics','Swimming','Gymnastics','Rowing','Fencing','Cycling']
# countries = ['United States','China','Romania','France']

# y = df[df['Team'].isin(countries)]
# y = y[y['Sport'].isin(sportsFilter)]


# y = y[y['Year'] > 2013]
# y.shape

# y.to_csv('C:\\Rekha\\InputFiles\\Sports_Event_Medal_Dataset_temp.csv')
# y.Team.unique()

# %%
#Selection
df[(df.Age>40) & (df.Age<60)]
# To get the count of records.Age.count()

# %%
df[df.Age == df.Age.max()]

# %% [markdown]
# #### Perfroming sort on column names and column data
# * Using sort_index() and sort_values()

# %%
df.sort_index(axis=1,ascending=True)

# %%
df.sort_values(by=['Team',"Sport"],ascending=[True,False])
df.head(2)

# %% [markdown]
# #### Get Descriptive statistics on Numerical Data

# %%
cols = ['Age','Height','Weight']
df[cols].describe()
# Out:
#                  Age         Height         Weight
# count  261642.000000  210945.000000  208241.000000
# mean       25.556898     175.338970      70.702393
# std         6.393561      10.518462      14.348020
# min        10.000000     127.000000      25.000000
# 25%        21.000000     168.000000      60.000000
# 50%        24.000000     175.000000      70.000000
# 75%        28.000000     183.000000      79.000000
# max        97.000000     226.000000     214.000000

# %% [markdown]
# #### Performing Aggregation operation
# #### Get the min, and max values for Age, Height, Weight

# %%
df[['Height','Age','Weight']].aggregate(['max','min']) # mean, var, std, sum
# Out:
#      Height   Age  Weight
# max    0.25  97.0   214.0
# min    0.14  10.0    25.0

# %%
df["Year"].unique()
# Out:
# array([2016, 2014, 2012, 2010, 2008, 2006, 2004, 2002, 2000, 1998, 1996,
#        1994, 1992, 1988, 1984, 1980, 1976, 1972, 1968, 1964, 1960, 1956,
#        1952, 1948, 1936, 1932, 1928, 1924, 1920, 1912, 1908, 1906, 1904,
#        1900, 1896], dtype=int64)

# %% [markdown]
# #### Sports Participation Table

# %%
df["Sport"].value_counts()
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %% [markdown]
# ### Groupby

# %% [markdown]
# ### Top participating countries

# %%
collist = ['Team','ID']
df_chart1 = df[collist].groupby(["Team"]).agg("count")
df_chart1
df_chart1 = df_chart1.sort_values(by=["ID"],ascending=False)[:10].reset_index()
df_chart1
# Out:
#             Team     ID
# 0  United States  17847
# 1         France  11988
# 2  Great Britain  11404
# 3          Italy  10260
# 4        Germany   9326
# 5         Canada   9279
# 6          Japan   8289
# 7         Sweden   8052
# 8      Australia   7513
# 9        Hungary   6547

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Team",y="ID",data=df_chart1)
plt.title = "Top Participating countries"
plt.show()

# %% [markdown]
# ### Find mean participation by country

# %%
collist = ['Year','Team','ID']
df_chart2 = df[collist].groupby(["Year","Team"]).agg("count") \
            .reset_index() \
            .drop(columns =['Year']) \
            .groupby(["Team"]).agg("mean").reset_index() \
            .sort_values(by="ID",ascending=False)

# .groupby("Team").agg("mean")
df_chart2[:10]
# Out:
#                Team          ID
# 1087   Unified Team  832.000000
# 976    Soviet Union  553.500000
# 1148   West Germany  533.166667
# 1095  United States  509.914286
# 301    East Germany  423.833333
# 398         Germany  358.692308
# 361          France  342.514286
# 412   Great Britain  325.828571
# 872          Russia  307.625000
# 506           Italy  293.142857

# %% [markdown]
# ### Total Gold Medals by country

# %%
collist = ['Team','Medal','ID']
df_chart2 = df[collist].groupby(["Team","Medal"]).count()
df_chart2
df_chart2 = df_chart2.reset_index()
cond = df_chart2["Medal"] == "Gold"
df_chart2= df_chart2[cond].sort_values(by="ID",ascending=False)[:6]
df_chart2
# Out:
#               Team Medal    ID
# 726  United States  Gold  2474
# 627   Soviet Union  Gold  1058
# 263        Germany  Gold   679
# 351          Italy  Gold   535
# 277  Great Britain  Gold   519
# 240         France  Gold   455

# %% [markdown]
# ### Top 8 countries by Gold Medal

# %%
df_gold = df[df["Medal"]=="Gold"].groupby("Team").Medal.count().reset_index()

df_gold = df_gold.sort_values(by="Medal",ascending=False)[:8]
df_gold
# Out:
#               Team  Medal
# 224  United States   2474
# 200   Soviet Union   1058
# 87         Germany    679
# 112          Italy    535
# 90   Great Britain    519
# 80          France    455
# 205         Sweden    451
# 102        Hungary    432

# %%
plt.figure(figsize=(10,6))
plt.title("Top Countires By Gold Medal")
sns.barplot(data=df_gold,x="Team",y="Medal")
# Out:
# <AxesSubplot:title={'center':'Top Countires By Gold Medal'}, xlabel='Team', ylabel='Medal'>

# %% [markdown]
# #### Scatter plot of Medals distribution over year

# %%
df["Medal"].fillna("None",inplace=True)
df["Medal_Int"] = df["Medal"]
df["Medal_Int"].replace(["Gold","Silver","Bronze","None"],[1,2,3,4],inplace=True)
df_medals = df.groupby(["Year","Medal"]).count().reset_index()

# %%
sns.scatterplot(x="Year",y="ID",size="Medal",hue="Medal",data=df_medals[df_medals["Medal"] !="None"])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='ID'>

# %%
# Calculate rolling avg by year
cols = ["Year","ID"]
df1 = df[cols].groupby(["Year"]).count().reset_index()[:5]
df1["Moving_Avg"] = df1.rolling(window=5).mean().ID
df1[:6]
# Out:
#    Year    ID  Moving_Avg
# 0  1896   380         NaN
# 1  1900  1936         NaN
# 2  1904  1301         NaN
# 3  1906  1733         NaN
# 4  1908  3101      1690.2

# %% [markdown]
# ###  Scatter plot and Line Plot

# %%
df_entries = df.groupby(["Year"]).count().reset_index()
df_entries[:6]
# Out:
#    Year    ID  Name  Gender   Age  Height  Weight  Team   NOC  Games  Season  \
# 0  1896   380   380     380   217      46      49   380   380    380     380
# 1  1900  1936  1936    1936  1146     116      79  1936  1936   1936    1936
# 2  1904  1301  1301    1301  1027     213     147  1301  1301   1301    1301
# 3  1906  1733  1733    1733   990     257     205  1733  1733   1733    1733
# 4  1908  3101  3101    3101  2452     475     483  3101  3101   3101    3101
# 5  1912  4040  4040    4040  3884     721     596  4040  4040   4040    4040
#
#    City  Sport  Event  Medal  Medal_Int
# 0   380    380    380    380        380
# 1  1936   1936   1936   1936       1936
# 2  1301   1301   1301   1301       1301
# 3  1733   1733   1733   1733       1733
# 4  3101   3101   3101   3101       3101
# 5  4040   4040   4040   4040       4040

# %%
moving_avg = df_entries.rolling(window=5).mean()
moving_avg[:6]

# %%
moving_avg["Year"] = df_entries["Year"]
moving_avg[:6]

# %%
cum_sum = df_entries.rolling(window=5).sum()
cum_sum["Year"] = df_entries["Year"]

# %%
sns.scatterplot(x="Year",y="ID",size="Medal",hue="Medal",data=df_medals)
sns.lineplot(x="Year",y="ID",data=moving_avg)
sns.lineplot(x="Year",y="ID",data=cum_sum)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='ID'>

# %%
cum_sum["Year"] = df_entries["Year"]
cum_sum["Rolling_Sum"]= df_entries.rolling(window=3).ID.sum()
cum_sum[:6]
# Out:
#    Year       ID     Name   Gender     Age  Height  Weight     Team      NOC  \
# 0  1896      NaN      NaN      NaN     NaN     NaN     NaN      NaN      NaN
# 1  1900      NaN      NaN      NaN     NaN     NaN     NaN      NaN      NaN
# 2  1904      NaN      NaN      NaN     NaN     NaN     NaN      NaN      NaN
# 3  1906      NaN      NaN      NaN     NaN     NaN     NaN      NaN      NaN
# 4  1908   8451.0   8451.0   8451.0  5832.0  1107.0   963.0   8451.0   8451.0
# 5  1912  12111.0  12111.0  12111.0  9499.0  1782.0  1510.0  12111.0  12111.0
#
#      Games   Season     City    Sport    Event    Medal  Medal_Int  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 4   8451.0   8451.0   8451.0   8451.0   8451.0   8451.0     8451.0
# 5  12111.0  12111.0  12111.0  12111.0  12111.0  12111.0    12111.0
#
#    Rolling_Sum
# 0          NaN
# 1          NaN
# 2       3617.0
# 3       4970.0
# 4       6135.0
# 5       8874.0

# %%
sns.lineplot(x="Year",y="Rolling_Sum",data=cum_sum)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rolling_Sum'>

# %% [markdown]
# #### Analyze pattern in height of participant

# %%
country_list = ["United States","Soviet Union","Germany","Italy","India"]
df_temp = df[df['Team'].isin(country_list)]
sns.boxplot(x='Height',y='Team',data=df_temp)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Team'>

# %% [markdown]
# #### Analyze the pattern in height, weight by gender, by medal

# %%
country_list = ["United States","Soviet Union","Germany","Italy","India"]
df_temp = df[df['Team'].isin(country_list)]
sportsFilter = ['Athletics','Swimming','Gymnastics','Rowing','Fencing','Cycling']
df2 = df_temp[df_temp['Sport'].isin(sportsFilter)]

sns.scatterplot( x="Height", y='Weight',hue='Medal',size="Gender", data=df2)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
### Correlation matrix

# %%
corr = df.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
            annot=True)
# Out:
# <AxesSubplot:>

# %%
## Which country has maximum female participation
df_female = df.groupby(["Team","Gender"]).ID.count()
df_female = df_female.reset_index()
df_female.sort_values(by=["Gender","ID"],ascending=[True,False])
# Out:
#                Team Gender    ID
# 1418  United States      F  5368
# 224          Canada      F  3473
# 531   Great Britain      F  3188
# 512         Germany      F  2911
# 467          France      F  2743
# ...             ...    ...   ...
# 1456   Uzbekistan-2      M     1
# 1464    Verveine-19      M     1
# 1465    Verveine-41      M     1
# 1496        Whisper      M     1
# 1498   Whitini Star      M     1
#
# [1528 rows x 3 columns]

# %%
## Identify repeat winners
df_repeat = df[df["Medal"].isin(["Gold"])]
df_repeat = df_repeat.groupby("Name").count()
df_r = df_repeat.reset_index().sort_values(by="ID",ascending=False)
df_r[df_r["ID"] > 1]
# Out:
#                                       Name  ID  Gender  Age  Height  Weight  \
# 6633               Michael Fred Phelps, II  23      23   23      23      23
# 7836           Raymond Clarence "Ray" Ewry  10      10   10      10      10
# 7386                  Paavo Johannes Nurmi   9       9    9       9       9
# 5591    Larysa Semenivna Latynina (Diriy-)   9       9    9       9       9
# 6336                     Mark Andrew Spitz   9       9    9       9       9
# ...                                    ...  ..     ...  ...     ...     ...
# 3667  Hazel Virginia Wightman (Hotchkiss-)   2       2    2       0       0
# 4950           Joy Lynn Fawcett (Biefeld-)   2       2    2       2       2
# 1203                Briana Collette Scurry   2       2    2       2       2
# 1202                  Brian Stuart Goodell   2       2    2       2       2
# 5158                          Karl Schulze   2       2    2       2       2
#
#       Team  NOC  Games  Year  Season  City  Sport  Event  Medal  Medal_Int
# 6633    23   23     23    23      23    23     23     23     23         23
# 7836    10   10     10    10      10    10     10     10     10         10
# 7386     9    9      9     9       9     9      9      9      9          9
# 5591     9    9      9     9       9     9      9      9      9          9
# 6336     9    9      9     9       9     9      9      9      9          9
# ...    ...  ...    ...   ...     ...   ...    ...    ...    ...        ...
# 3667     2    2      2     2       2     2      2      2      2          2
# 4950     2    2      2     2       2     2      2      2      2          2
# 1203     2    2      2     2       2     2      2      2      2          2
# 1202     2    2      2     2       2     2      2      2      2          2
# 5158     2    2      2     2       2     2      2      2      2          2
#
# [1995 rows x 16 columns]
