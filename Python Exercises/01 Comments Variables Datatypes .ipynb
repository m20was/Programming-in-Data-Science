# %% [markdown]
# <h3 style="color:blue;">Coding standards and convention </h3>

# %% [markdown]
# Naming Convention:
# Examples include MAX_OVERFLOW and TOTAL.
# Variable name:
# i_am_a_variable (camel case)
# ClassNames
# Class names should normally use the CapWords(IAmAClass) convention.

# %% [markdown]
# <h3 style="color:blue;"> Comments: </h3>

# %%
#This is a comment
#written in
#more than just one line
print("Hello, World!")
# Out:
# Hello, World!

# %%
# Unassigned string
"""
This is a comment
written in
more than just one line
"""

print("Hello, World!")

# %% [markdown]
# <h3 style="color:blue;">
# Variables :
# Variables are containers for storing data values.
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it.
# </h3>

# %% [markdown]
# <h3 style="color:blue;">
# Variables are containers for storing data values. <br\>
# 1.Python has no command for declaring a variable. <br\>
# 2. A variable is created the moment you first assign a value to it. <br\>
# 3. Python allows you to assign values to multiple variables in one line <br\>
# 4. The Python print statement is often used to output variables. <br\>
# 5. Global Variables, Variables that are created outside of a function (as in all of the examples above) are known <br/>
#   global variables. Global variables can be used by everyone, both inside of functions and outside. <br\>
# 6. Data Casting allows to change the data types of a variable
# </h3>

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
x = 4
y = int("str")
print(y)

print(x+y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-eb90510800e1> in <module>
#       1 x = 4
# ----> 2 y = int("str")
#       3 print(y)
#       4
#       5 print(x+y)
#
# ValueError: invalid literal for int() with base 10: 'str'

# %%
x = ["apple", "banana", "cherry"]
print(x)
print(type(x))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %% [markdown]
# <h3 style="color:blue;">Naming convention </h3>
# <h4 style="color:blue;">
# <p>A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). </p>
# <p>Rules for Python variables:
#     <ul>
#         <li>A variable name must start with a letter or the underscore character </li>
#         <li>A variable name cannot start with a number </li>
#         <li>A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ) </li>
#         <li>Variable names are case-sensitive (age, Age and AGE are three different variables) </li>
#     </ul>
# </p>
# </h4>

# %%
# Example of variable declaration
# Legal Naming convention
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"
a= 5
A= 7
print(a,",",A)
# Out:
# 5 , 7

# %%
# Illegal naming convenation
#2myvar = "John"
#my-var = "John"
my var = "John"
# Out:
#   File "<ipython-input-14-86e598baf39d>", line 4
#     my var = "John"
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Asssigning values to variable

# %%
# Assign multiple values to multiple variables
x, y, z = "Orange", "Banana" , "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# Output Statement
x = 5
y = "7"

print(type(y))

#print(str(x) + y)
# Out:
# <class 'str'>
