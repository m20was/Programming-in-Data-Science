# %%
import datetime as dt

x = dt.datetime.now()
print(x)
# Out:
# 2022-08-23 23:29:40.207140

# %%
import datetime as dt

x = dt.datetime(2020, 5, 17)

print(x)
# Out:
# 2020-05-17 00:00:00

# %%
import datetime as dt
# yy,mm,dd
x = dt.datetime(2018, 12, 1)

print(x.strftime("%B"))
print(x.strftime("%x"))
# Out:
# December
# 12/01/18

# %%
from datetime import datetime, date, time

x=datetime.strptime('2009-31-10', '%Y-%d-%m')
print(x)
# Out:
# 2009-10-31 00:00:00

# %%
dt2 = datetime(2011, 11, 15, 22, 30)
dt1 = datetime(2011, 11, 16)
delta = dt1 -dt2
print(delta)
# Out:
# 1:30:00

# %%
import datetime as dt
# Add days to a date


start_date = "01/01/2020"
dt1 = dt.datetime.strptime(start_date, "%m/%d/%Y")
x = dt1 + dt.timedelta(days=25)
print(x)
# Out:
# 2020-01-26 00:00:00

# %%
x = datetime(2011, 10, 29, 20, 30, 21)
print(x.day," ", x.minute)
# Out:
# 29   30

# %%
x.strftime('%m/%d/%Y %H:%M')
# Out:
# '10/29/2011 20:30'
